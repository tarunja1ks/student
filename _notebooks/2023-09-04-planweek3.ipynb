# %% [markdown]
# ---
# layout: post
# title: Week 3 Plan
# description: A Tech Talk on Linux and the Bash shell.
# toc: true
# comments: true
# categories: [5.A, C4.1]
# courses: { compsci: {week: 3, categories: [6.B]} }
# type: plans
# ---

# %% [markdown]
# ## Week 3 Plan
# My partner and I have huge plans for this week involving the showcase. One thing we want to add to our website is an email classifier, which includes checking if emails or spam or not. I would also like to make a feature to add data to the trianing set to any people experiencing spam emails. Another thing, we wanted to do was make a subpage that could tell the weather for anywhere in the world at any current time.
